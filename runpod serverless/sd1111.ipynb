# %%
from dotenv import load_dotenv
import os
load_dotenv()

RUNPOD_API_KEY = os.getenv("RUNPOD_API_KEY")
RUNPOD_ENDPOINT_ID = 'sw0tgzmaqgxyvp'

# %%
import requests

headers = {
    'Content-Type': 'application/json',
    'Authorization': f'Bearer {RUNPOD_API_KEY}'
}

quality_tags = '(masterpiece, realistic, best quality, ultra-detailed, high resolution, intricate design, 8K, photorealistic, professional lighting)'
data = {
  'input': {
  "prompt": "A futuristic robot girl with glowing neon circuits, sleek metallic body, and expressive cybernetic eyes, wearing a high-tech bodysuit. Standing in a sci-fi cityscape with neon lights reflecting off wet streets." + quality_tags,
  "negative_prompt": "blurry, low quality, pixelated, distorted, deformed hands, extra limbs, asymmetrical features, text, watermark",
  "width": 512,
  "height": 768,
    # "batch_size": 4,
#   "samples": 1,
#   "num_inference_steps": 50,
#   "guidance_scale": 7.5,
#   "seed": null,
#   "safety_checker": "yes",
#   "enhance_prompt": "yes",
#   "multi_lingual": "no",
#   "panorama": "no",
#   "self_attention": "yes",
#   "upscale": "no",
#   "embeddings_model": "default",
#   "webhook": null,
#   "track_id": "robotgirl_001"
}
}

response = requests.post(f'https://api.runpod.ai/v2/{endpoint_id}/run', headers=headers, json=data)

# %%
status_headers = {
    'Authorization': f'Bearer {RUNPOD_API_KEY}'
}
job_id = response.json().get('id')
response_img = requests.get(f'https://api.runpod.ai/v2/{endpoint_id}/status/{job_id}', headers=status_headers)
response_img.json().get('status')
# Out:
# 'COMPLETED'

# %%
images = response_img.json().get('output').get('images')

from utils import display_image

for image in images:
    continue
    display_image(image)

# %%
import time

response = requests.post(f'https://api.runpod.ai/v2/{endpoint_id}/run', headers=headers, json=data)

status_headers = {
    'Authorization': f'Bearer {RUNPOD_API_KEY}'
}

job_id = response.json().get('id')

while True:
    response_img = requests.get(f'https://api.runpod.ai/v2/{endpoint_id}/status/{job_id}', headers=status_headers)
    status = response_img.json().get('status')
    if status == "COMPLETED":
        break
    time.sleep(1)

image = response_img.json().get('output').get('images')[0]

from utils import display_image

display_image(image)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=67x100>

# %%
# Out:
# '...'

# %%
import time
import threading
from utils import display_image

def process_request(thread_id, data):

    start_time = time.time()

    response = requests.post(f'https://api.runpod.ai/v2/{endpoint_id}/run', headers=headers, json=data)
    job_id = response.json().get('id')

    status_headers = {'Authorization': f'Bearer {RUNPOD_API_KEY}'}

    counter = 0

    while True:
        response_img = requests.get(f'https://api.runpod.ai/v2/{endpoint_id}/status/{job_id}', headers=status_headers)
        status = response_img.json().get('status')

        if status == "COMPLETED":
            break

        if counter %10 == 0:

            elapsed_time = time.time() - start_time
            print(f"Thread {thread_id} running for {elapsed_time:.2f} seconds.")

        counter += 1
        time.sleep(1)

    image = response_img.json().get('output').get('images')[0]
    elapsed_time = time.time() - start_time
    print(f"Thread {thread_id} completed in {elapsed_time:.2f} seconds.")

    display_image(image)

threads = []

for i in range(6):
    thread = threading.Thread(target=process_request, args=(i, data))
    threads.append(thread)
    thread.start()

# Wait for all threads to complete
for thread in threads:
    thread.join()

print("All requests completed.")
# Out:
# Thread 1 running for 1.78 seconds.
# Thread 0 running for 1.93 seconds.
# Thread 4 running for 1.94 seconds.
# Thread 2 running for 2.00 seconds.
# Thread 5 running for 2.10 seconds.
# Thread 3 running for 2.24 seconds.
# Thread 1 running for 3.33 seconds.
# Thread 4 running for 3.57 seconds.
# Thread 0 running for 3.71 seconds.
# Thread 2 running for 3.77 seconds.
# Thread 3 running for 3.83 seconds.
# Thread 5 running for 3.93 seconds.
# Thread 1 running for 4.99 seconds.
# Thread 4 running for 5.10 seconds.
# Thread 0 running for 5.28 seconds.
# Thread 2 running for 5.43 seconds.
# Thread 5 running for 5.59 seconds.
# Thread 3 running for 5.68 seconds.
# Thread 4 running for 6.67 seconds.
# Thread 1 running for 6.72 seconds.
# Thread 2 running for 6.98 seconds.
# Thread 5 running for 7.23 seconds.
# Thread 3 running for 7.30 seconds.
# Thread 2 running for 8.70 seconds.
# Thread 0 completed in 8.76 seconds.
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=67x100>
# Thread 5 running for 8.91 seconds.
# Thread 3 running for 9.14 seconds.
# Thread 1 completed in 9.19 seconds.
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=67x100>
# Thread 4 completed in 9.22 seconds.
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=67x100>
# Thread 2 running for 10.31 seconds.
# Thread 5 running for 10.47 seconds.
# Thread 3 running for 10.74 seconds.
# Thread 2 running for 11.94 seconds.
# Thread 5 running for 12.09 seconds.
# Thread 3 running for 12.39 seconds.
# Thread 2 running for 13.45 seconds.
# Thread 5 running for 13.82 seconds.
# Thread 3 running for 13.92 seconds.
# Thread 2 completed in 15.87 seconds.
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=67x100>
# Thread 3 completed in 16.59 seconds.
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=67x100>
# Thread 5 completed in 17.25 seconds.
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=67x100>
# All requests completed.
