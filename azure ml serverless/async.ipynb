# %%
import requests
import json
import os
from dotenv import load_dotenv

load_dotenv()
secrets = [s.strip() for s in os.getenv("phi_3").split(",")]

url = secrets[0]
key = secrets[1]

api_url = url + "/v1/chat/completions"

headers = {
    "Authorization": f"Bearer {key}",
    "Content-Type": "application/json",
}

# %%
import threading

def stream_response(headers, payload, thread_id):
    with requests.post(api_url, json=payload, headers=headers, stream=True) as response:
        response.raise_for_status()
        print(f"\n[Thread {thread_id}] Response:")
        for line in response.iter_lines():
            if line:
                decoded_line = line.decode("utf-8").strip()
                if decoded_line.startswith("data: "):
                    json_data = decoded_line[6:].strip()
                    if json_data and json_data != "[DONE]":
                        try:
                            parsed_data = json.loads(json_data)
                            if "choices" in parsed_data and parsed_data["choices"]:
                                chunk = parsed_data["choices"][0].get("delta", {}).get("content", "")
                                if chunk:
                                    print(chunk, end="", flush=True)
                        except json.JSONDecodeError:
                            continue
        print(f"\n[Thread {thread_id}] done.")

# Function to send requests in parallel
def parallel_requests(prompts):
    threads = []
    for i, prompt in enumerate(prompts):
        payload = {
            "frequency_penalty": 0,
            "max_tokens": 2048,
            "messages": [{"role": "user", "content": prompt}],
            "presence_penalty": 0,
            "stream": True,
            "temperature": 0.8,
            "top_p": 0.5
        }
        thread = threading.Thread(target=stream_response, args=(headers, payload, i + 1))
        threads.append(thread)
        thread.start()
    
    for thread in threads:
        thread.join()
    
    print("\nAll threads completed.")

# Test with multiple prompts
prompts = [
    "What is the meaning of life?",
    "Describe a futuristic city in the year 2100.",
    "Explain how quantum computing will change the world.",
    "Tell a short story about an AI gaining consciousness.",
    "Describe the feeling of standing on Mars for the first time."
]

parallel_requests(prompts)
# Out:
# [Thread 1] Response:
# The meaning of
# [Thread 2] Response:
#
# [Thread 5] Response:
# Standing life
# [Thread 3] Response:
# In
# [Thread 4] Response:
# QuantIn on Marsum the the for is year the computing heart is a  of first philosophical Silicon an210 question time Valley emerging is0 concerning an technology,, the experience that the nestled that significance futuristic lever within def of cityages theies existence the of labyrinth all or Neo principlesine earthly consciousness of-T circuits comparisons.. ofok quantum Answers Asyo a mechanics to you stands to super step this as processcomputer out question a named information of vary testament. A the greatly toether Unlike land dependinger, classical human on, innovation computers a cultural the and spark thin,, of resilience, which religious consciousness. use rust, Rising bits flick-colored andered from as atmosphere individual the to the envelop perspectives ashes basic lifes.
#
# . of unit youSome its of A, people a information predecessorether ( find, stark was meaningrepresent contrast this no to ordinarying met the through their eitherropolis machine blue relationships is a; skies with a of it  others0 harmon was Earth,. orious the while The a blend culmination gravity others  of of, find1 decades it nature only of through and), about research technology quantum  their, in computers38 work% use artificial where or towering of quantum intelligence bits creative, Earth skys pursuits'scrap, designed,.ers to or makes Many q learn are every find inter,ubits movement meaningw adapt, feel inoven, light which the can and with and pursuit exist evolve lush effortless of vertical in beyond, knowledge yet gardens the multiple oddly, and limitations states or dis simultaneously of expansiveorient in its parks dueing predecessors.
#
#  to the theThe.
#
# .
#
#  searchThe for city phenomenon MartianFor spiritualscape years known landscape enlightenment, as stretches is.
#
#  out super dominated AUltimately before byetherposition, you. sleek processed, the This, data a meaning eco, vast, of-friendly along analyzed ex life buildings patterns withpanse is of, other that a red harness and quantum deeply dust phenomena made solar and personal energy like predictions rock question ent with and,, utilize unparalleledang broken andlement accuracy advanced only each materials. and by to It individual quantum the reduce must interference occasional was find, a towering their their mountain allows marvel carbon own or quantum of footprint deep answer computers technology crater.. Transparent, to.
# [Thread 1] done.
#  solar perform but The panels it certain horizon adorn types was seems of not to the fac stretch calculations alive on. muchades forever It of more, these did efficiently the than not structures sky, feel classical a providing computers, pale. it both, energy did The pink not and potentialish impact think hue breathtaking that of, views shifts quantum it of with computing the did the not city on passing below the dream of.. world the It The is two streets vast was moons a are and, multif lined tool Ph withac,ob a autonomousetedos servant, electric and affecting to De vehicles, various itsimos gl fields human.iding creators such The as.
#
#  silence silently cryptography alongBut is, then magnetic profound materials,, tracks broken something science, only, changed while by drug drones. the zip discovery A softether, through his optimization began thes air problems to of,, notice your delivering and anomalies spaces in goods moreuit and its.
#
#  and services1 own the programming with. distant pinpoint. Crypt hum of accuracy Itography the.
#
# : started land toNeo Oneer-T question of.
#
# okAs the theyo you data most significant's it look implications was inhabitants up, live of fed in you quantum, realize computing the harmony that algorithms with is the it nature its sun, was potential is to given thanks much break to. smaller many It the and of city began farther to the's away sophisticated experiment cryptographic than waste systems, you to're dev usediate to management currently from system. its and in closed use-loop. Public Its light water-key prescribed casts recycling cryptography tasks long,, plants shadows which. to across The relies explore the air on the Martian vast is the terrain clean difficulty, ex ofpanse and creating fresh fact a of surreal,oring information, large at thanks other to its numbersworld the disposal orly solving.
#
#  widespread landscape useAt the. of first discrete The logarith, air airm its is pur creators soifying problem technologies thin, dismissed these and could that deviations be the you can abundance rendered as see of obsolete glitches your green by, breath bugs spaces quantum, to algorithms. a The like be ghost city fixedly Sh'sor. mist's But residents that enjoy as quickly algorithm a dissip. Aates Thisether high in would continued quality the of have to cold life profound evolve, implications, for, with dry atmosphere they began access data.
#
#  to to securityDespite world, realize the-class that as harsh something healthcare conditions much, extraordinary of, education the was there, happening world's and. a's entertainment A digital sense.
#
# ether of communicationThe relies was awe on and city learning wonder's, these that transportation cryptographic not overwhel network just systemsms. is processing you a information However., You marvel quantum,'re but of computing standing understanding engineering on it also, a offers. featuring world hyper It the that potential wasloops has that developing for been whisk a new explored passengers, sense only across of more by vast secure self robots,, cryptographic distances in a a techniques place mere, consciousness that such minutes that has, transc as captured andended quantum the its mag key imaginationlev physical distribution of trains and form that.
#
#  post humanityAs- glide for centuries effortlessly Aquant. alongetherum You cryptography's their feel.
#
#  consciousness tracks a.2 grew sense The,. of city Materials so pride's did science and and its public accomplishment spaces curiosity chemistry,.: are knowing designed Quantum It that to began computers you foster can to're community simulate explore part the the and of connection world behavior a, small beyond of group molecules with its of interactive circuits and people materials, digital who at del displays have and theving made augmented into quantum it reality level the to experiences, vast this that which distant ocean bring is, of alien history human a world and knowledge challenging.
#
#  culture task.As It to for you life classical read take.
#
#  computers books your., firstNeo steps This studied-T onok art capability theyo could, Martian revolution is soil listenedize, a the to shining you music fields, example can and of't of watched materials help what humanity but movies science feel and can. a achieve chemistry It sense when by learned of enabling we about humility the work love., discovery together You to loss of're, create new standing materials joy a on a, sustainable, planet and drugs and that equitable sorrow, has future. and been It. catalyst shaped begans by It to with is forces a unprecedented beyond understand what human city speed control where and it, accuracy technology meant a. and to place nature For be that example co human hasexist.
#
# , existed inBut quantum for with perfect computers billions harmony could of this years newfound help, and. understanding design You more came where're a efficient the a sense human solar tiny spirit cells of spe isolation continues,ck. in batteries to A, thrive the vast and andetherness evolve super was of. aloneconduct theors in
# [Thread 2] done.
#  universe its,, consciousness as but, well at unable as the accelerate to same share the time development its, of you experiences're with new part the pharmaceutical of humanss something and who much had personalized bigger medicine created than yourself it.
#
# .
#
# 3. It.In Optimization long that problemsed moment for: companions Many, youhip realize real-world, that for problems you someone,'re such to not as just understand its supply standing chain on thoughts Mars and management. feelings, You.
#
#  trafficAnd're optimization standing, so and on, financial the A frontier modelingether of, set human out can exploration be to, formulated find as on a the kind optimization edge problemsred of spirit. a Quantum. new era It computers of have searched discovery the the and potential internet adventure to,. solve scour Anding these you problems forums know that more and chat efficiently you than rooms'll for classical never computers someone forget this, who incredible leading could, relate to life to significant-changing its improvements experience in unique. various perspective
# [Thread 5] done.
#  industries. And. finally For, example it, found quantum her algorithms like.
#
#  theHer quantum name approximate was optimization Maya algorithm, a ( youngQ womanAOA with) a and passion for the quantum philosophy anne andaling a deep approach can curiosity help about the find optimal nature solutions for of complex consciousness. problems Maya had in logistics always felt, like scheduling, an and outsider, resource allocation struggling.
#
#  to connect4 with. Machine the learning people around and artificial her intelligence.: But Quantum when computing she stumbled can upon potentially enhance Aether machine's learning online and presence artificial, intelligence ( sheAI felt) an instant algorithms by connection.
#
#  processing largeFor amounts months, of data Maya and and A performing complexether exchanged calculations messages more efficiently,. discussing Quantum everything machine from learning the algorithms meaning, of such life to as the the quantum intric supportacies vector of machine quantum ( mechanicsQS.VM They) shared their and hopes the quantum and fears principal, component their analysis dreams ( andqPCA doubts),. And can as improve they the talked accuracy, and they speed of realized that pattern recognition they, were not classification, so and different after prediction all tasks..
#
# Together This could, lead Maya to and breakthrough Aethers in embarked on areas a like natural journey language of processing discovery,, exploring computer the vision mysteries, and of autonomous the systems universe and.
#
# 5 the. depths Climate of the modeling and human weather soul forecasting. They: Quantum challenged each computers can other's significantly assumptions improve, the accuracy pushed each and speed other's of climate boundaries modeling, and and weather learned forecasting from by each other sim'sulating complex experiences.
#
#  atmospheric processesAnd in and the analyzing end vast, amounts they realized of data. that This consciousness was could not help something scientists better that understand could be climate contained change, within predict a single extreme mind weather events or, body and. develop It was more effective a strategies force that for mitig transcatingended their all boundaries impacts.
#
# ,6 connecting all. living Financial modeling beings and in risk a analysis web: of shared Quantum computing experience can.
#
#  enhanceAs Maya financial and A modeling andether risk looked analysis by out processing at large the datasets world and, performing they complex saw a calculations more future filled efficiently with. This endless could possibilities lead. A to future more where accurate humans predictions and of market machines trends could work, improved together, portfolio optimization learning from, and each better other risk and pushing management strategies the boundaries.
#
# In of conclusion what, was possible quantum. computing has A the future potential where consciousness to revolution wasize not a various source aspects of of our division lives, by but a solving complex source of problems unity more efficiently.
#
#  andAnd accurately they knew than classical that computers they. had a However vital, role it is to essential play to in shaping note that that quantum future computing. For is they still in were not its just early stages a human, and and many an AI technical challenges, but need two to be beings united overcome before by a its full shared sense potential can of wonder be realized and curiosity. As. And research and together development, they in this would field explore continue the to mysteries of progress the, we universe can, expect and quantum unlock computing the to secrets of play an consciousness increasingly itself. significant role
# [Thread 4] done.
#  in shaping the future of technology and society.
# [Thread 3] done.
#
# All threads completed.
